# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt
from datetime import timedelta
from datetime import time

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Get column names from Measurement Table
inspector = inspect(engine)

measurement_columns = inspector.get_columns('measurement')
for column in measurement_columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get column names from Station table
station_columns = inspector.get_columns('station')
for column in station_columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data


precip = session.query(Measurement.id, Measurement.station, Measurement.date, Measurement.prcp, Measurement.tobs).order_by(Measurement.date.desc())

precip_df = pd.DataFrame(precip, columns=['id','Station','Date','Precipitation','Temp']).fillna(0)

precip_df['Date'] = pd.to_datetime(precip_df['Date'], format='%Y-%m-%d', errors='coerce')


last_date = precip_df.Date[0]
one_yr_from_last = last_date - dt.timedelta(days=365)

precip_df_filtered = precip_df[precip_df['Date']>= one_yr_from_last].fillna(0)

precip_df_filtered.set_index('Date', inplace=True)

ax = precip_df_filtered['Precipitation'].plot(kind='line', figsize=(15,10), legend=True, grid=True)
ax.set_ylabel('Precipitation', fontsize=20)
ax.set_xlabel('One Year', fontsize=20)
plt.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

precip_df_filtered.Precipitation.describe()
# Out:
# count    2230.000000
# mean        0.160664
# std         0.442067
# min         0.000000
# 25%         0.000000
# 50%         0.010000
# 75%         0.110000
# max         6.700000
# Name: Precipitation, dtype: float64

# %% [markdown]
# ### ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?

station = session.query(Station.id, Station.station, Station.name, Station.latitude, Station.longitude, Station.elevation)

station_df = pd.DataFrame(station, columns=['id','Station','Name','Latitude','Longitude','Elevation'])
station_df.set_index('id',inplace=True)

station_count = station_df['Station'].nunique()

print(station_count)
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

#join measurements on stations

observations = precip_df.merge(station_df, left_on='Station', right_on='Station')

observations.Station.value_counts()

observations_count = observations.Station.value_counts()

print(observations_count)
# Out:
# USC00519281    2772
# USC00519397    2724
# USC00513117    2709
# USC00519523    2669
# USC00516128    2612
# USC00514830    2202
# USC00511918    1979
# USC00517948    1372
# USC00518838     511
# Name: Station, dtype: int64

# %%
#ID of most active station

most_active_station_id = observations_count.index[0]
print(most_active_station_id)
# Out:
# USC00519281

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?

max_temp = observations.Temp.loc[observations['Station'] == most_active_station_id].max(skipna=True)
min_temp = observations.Temp.loc[observations['Station'] == most_active_station_id].min(skipna=True)
avg_temp = observations.Temp.loc[observations['Station'] == most_active_station_id].mean(skipna=True)


print(f'{most_active_station_id}: Lowest Temp: {min_temp} | Highest Temp: {max_temp} | Avg Temp: {avg_temp}')
# Out:
# USC00519281: Lowest Temp: 54.0 | Highest Temp: 85.0 | Avg Temp: 71.66378066378067

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

last_12_months = session.query(Measurement.id, Measurement.station, Measurement.date, Measurement.prcp, Measurement.tobs).filter(Measurement.station == most_active_station_id).filter(Measurement.date >= str(one_yr_from_last))#.order_by(Measurement.date.asc())

df = pd.read_sql_query(last_12_months.statement, engine)

df.set_index(df['date'], inplace=True)

df.head()
# Out:
#                id      station        date  prcp  tobs
# date
# 2016-08-24  14609  USC00519281  2016-08-24  2.15  77.0
# 2016-08-25  14610  USC00519281  2016-08-25  0.06  80.0
# 2016-08-26  14611  USC00519281  2016-08-26  0.01  80.0
# 2016-08-27  14612  USC00519281  2016-08-27  0.12  75.0
# 2016-08-28  14613  USC00519281  2016-08-28  0.60  73.0

# %%
ax = df['tobs'].plot(kind='hist', figsize=(15,10), legend=True, grid=True)
ax.set_ylabel('Frequency', fontsize=20)
plt.show()

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

start_vacation = '2017-02-20'
end_vacation = '2017-03-02'

# convert str to datetime, subtract one year
start_vacation_1yr_prev = dt.datetime.strptime(start_vacation,'%Y-%m-%d') - dt.timedelta(days=366)
end_vacation_1yr_prev = dt.datetime.strptime(end_vacation,'%Y-%m-%d') - dt.timedelta(days=366)

# call function
calc_temps(str(start_vacation_1yr_prev), str(end_vacation_1yr_prev))
# Out:
# [(60.0, 70.09375, 80.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

temp_results = calc_temps(str(start_vacation_1yr_prev), str(end_vacation_1yr_prev))

min_temp_1yr_prev = temp_results[0][0]
avg_temp_1yr_prev = temp_results[0][1]
max_temp_1yr_prev = temp_results[0][2]
peak_to_peak = [min_temp_1yr_prev, max_temp_1yr_prev]

#I can't get this to work despite many attempts
ax = plt.errorbar(['Avg Temp'],[avg_temp_1yr_prev],yerr=(min_temp_1yr_prev,max_temp_1yr_prev))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-fdee5444479c> in <module>
#      11 peak_to_peak = [min_temp_1yr_prev, max_temp_1yr_prev]
#      12
# ---> 13 ax = plt.errorbar(['Avg Temp'],[avg_temp_1yr_prev],yerr=(min_temp_1yr_prev,max_temp_1yr_prev))
#      14 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2575         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2576         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
# -> 2577         **({"data": data} if data is not None else {}), **kwargs)
#    2578
#    2579
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# group by station, sum rainfall

def rain_fall(start_date, end_date):
    return session.query(Station.station, 
                         Station.name, 
                         Station.latitude, 
                         Station.longitude, 
                         Station.elevation, 
                         func.sum(Measurement.prcp)).\
            join(Station, Station.station == Measurement.station).\
            filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# %%
rain_fall(str(start_vacation_1yr_prev), str(end_vacation_1yr_prev))
# Out:
# [('USC00519397',
#   'WAIKIKI 717.2, HI US',
#   21.2716,
#   -157.8168,
#   3.0,
#   1.9100000000000004)]

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# [(62.0, 69.15384615384616, 77.0),
#  (60.0, 69.39622641509433, 77.0),
#  (62.0, 68.9090909090909, 77.0),
#  (58.0, 70.0, 76.0),
#  (56.0, 67.96428571428571, 76.0),
#  (61.0, 68.96491228070175, 76.0),
#  (57.0, 68.54385964912281, 76.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
# Out:
#             tmin       tavg  tmax
# date
# 2018-01-01  62.0  69.153846  77.0
# 2018-01-02  60.0  69.396226  77.0
# 2018-01-03  62.0  68.909091  77.0
# 2018-01-04  58.0  70.000000  76.0
# 2018-01-05  56.0  67.964286  76.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
# Out:
# <img src="data:image/png;base64,..." width="640">
